# %% [markdown]
# <a href="https://colab.research.google.com/github/Adnan5603/brainybeam-task/blob/main/task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Perform advanced data cleaning techniques, such as fuzzy string matching for data deduplication.

# %%
import pandas as pd
from fuzzywuzzy import fuzz, process
# Out:
# /usr/local/lib/python3.12/dist-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
df = pd.read_csv("/tested.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
string_cols = df.select_dtypes(include='object').columns
print("String columns:", list(string_cols))
# Out:
# String columns: ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked']

# %%
for col in string_cols:
    df[col+"_clean"] = (
        df[col]
        .astype(str)
        .str.lower()
        .str.strip()
        .str.replace(r'[^a-z0-9 ]', '', regex=True)
    )

# %%
def get_matches(query, choices, scorer=fuzz.token_sort_ratio, limit=5, threshold=85):
    results = process.extract(query, choices, scorer=scorer, limit=limit)
    return [match for match, score in results if score >= threshold]

# %%
def deduplicate_column(col, threshold=90):
    unique_vals = df[col].dropna().unique()
    mapping = {}

    for val in unique_vals:
        matches = get_matches(val, unique_vals, threshold=threshold)
        if len(matches) > 1:
            standard = sorted(matches)[0]  # pick the first alphabetically
            for m in matches:
                mapping[m] = standard

    return mapping

# %%
for col in string_cols:
    mapping = deduplicate_column(col+"_clean", threshold=90)
    df[col+"_deduped"] = df[col+"_clean"].replace(mapping)

# %%
df[['Ticket', 'Ticket_clean', 'Ticket_deduped']].head(30)
# Out:
#               Ticket    Ticket_clean  Ticket_deduped
# 0             330911          330911          330911
# 1             363272          363272          363272
# 2             240276          240276          240276
# 3             315154          315154          315154
# 4            3101298         3101298         3101298
# 5               7538            7538            7538
# 6             330972          330972          330972
# 7             248738          248738          248738
# 8               2657            2657            2657
# 9          A/4 48871        a4 48871        a4 48871
# 10            349220          349220          349220
# 11               694             694             694
# 12             21228           21228           21228
# 13             24065           24065           24065
# 14       W.E.P. 5734        wep 5734        wep 5734
# 15     SC/PARIS 2167    scparis 2167    scparis 2166
# 16            233734          233734          233734
# 17              2692            2692            2692
# 18  STON/O2. 3101270  stono2 3101270  stono2 3101270
# 19              2696            2696            2696
# 20          PC 17603        pc 17603        pc 17603
# 21           C 17368         c 17368         c 17368
# 22          PC 17598        pc 17598        pc 17598
# 23          PC 17597        pc 17597        pc 17597
# 24          PC 17608        pc 17608        pc 17608
# 25         A/5. 3337         a5 3337         a5 3337
# 26            113509          113509          113509
# 27              2698            2698            2698
# 28            113054          113054          113054
# 29              2662            2662            2662

# %%
for col in string_cols:
    print(f"\n===== {col} =====")
    display(df[[col, col+"_clean", col+"_deduped"]].head(20))  # show first 20 rows for each column
# Out:
# ===== Name =====
#                                                  Name  \
# 0                                    Kelly, Mr. James
# 1                    Wilkes, Mrs. James (Ellen Needs)
# 2                           Myles, Mr. Thomas Francis
# 3                                    Wirz, Mr. Albert
# 4        Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5                          Svensson, Mr. Johan Cervin
# 6                                Connolly, Miss. Kate
# 7                        Caldwell, Mr. Albert Francis
# 8           Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9                             Davies, Mr. John Samuel
# 10                                   Ilieff, Mr. Ylio
# 11                         Jones, Mr. Charles Cresson
# 12      Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# 13                               Howard, Mr. Benjamin
# 14  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 15      del Carlo, Mrs. Sebastiano (Argenia Genovesi)
# 16                                  Keane, Mr. Daniel
# 17                                  Assaf, Mr. Gerios
# 18                       Ilmakangas, Miss. Ida Livija
# 19              Assaf Khalil, Mrs. Mariana (Miriam")"
#
#                                            Name_clean  \
# 0                                      kelly mr james
# 1                        wilkes mrs james ellen needs
# 2                             myles mr thomas francis
# 3                                      wirz mr albert
# 4            hirvonen mrs alexander helga e lindqvist
# 5                            svensson mr johan cervin
# 6                                  connolly miss kate
# 7                          caldwell mr albert francis
# 8               abrahim mrs joseph sophie halaut easu
# 9                               davies mr john samuel
# 10                                     ilieff mr ylio
# 11                           jones mr charles cresson
# 12          snyder mrs john pillsbury nelle stevenson
# 13                                 howard mr benjamin
# 14  chaffee mrs herbert fuller carrie constance to...
# 15          del carlo mrs sebastiano argenia genovesi
# 16                                    keane mr daniel
# 17                                    assaf mr gerios
# 18                         ilmakangas miss ida livija
# 19                    assaf khalil mrs mariana miriam
#
#                                          Name_deduped
# 0                                      kelly mr james
# 1                        wilkes mrs james ellen needs
# 2                             myles mr thomas francis
# 3                                      wirz mr albert
# 4            hirvonen mrs alexander helga e lindqvist
# 5                            svensson mr johan cervin
# 6                                  connolly miss kate
# 7                          caldwell mr albert francis
# 8               abrahim mrs joseph sophie halaut easu
# 9                               davies mr john samuel
# 10                                     ilieff mr ylio
# 11                           jones mr charles cresson
# 12          snyder mrs john pillsbury nelle stevenson
# 13                                 howard mr benjamin
# 14  chaffee mrs herbert fuller carrie constance to...
# 15          del carlo mrs sebastiano argenia genovesi
# 16                                    keane mr daniel
# 17                                    assaf mr gerios
# 18                         ilmakangas miss ida livija
# 19                    assaf khalil mrs mariana miriam
# ===== Sex =====
#        Sex Sex_clean Sex_deduped
# 0     male      male        male
# 1   female    female      female
# 2     male      male        male
# 3     male      male        male
# 4   female    female      female
# 5     male      male        male
# 6   female    female      female
# 7     male      male        male
# 8   female    female      female
# 9     male      male        male
# 10    male      male        male
# 11    male      male        male
# 12  female    female      female
# 13    male      male        male
# 14  female    female      female
# 15  female    female      female
# 16    male      male        male
# 17    male      male        male
# 18  female    female      female
# 19  female    female      female
# ===== Ticket =====
#               Ticket    Ticket_clean  Ticket_deduped
# 0             330911          330911          330911
# 1             363272          363272          363272
# 2             240276          240276          240276
# 3             315154          315154          315154
# 4            3101298         3101298         3101298
# 5               7538            7538            7538
# 6             330972          330972          330972
# 7             248738          248738          248738
# 8               2657            2657            2657
# 9          A/4 48871        a4 48871        a4 48871
# 10            349220          349220          349220
# 11               694             694             694
# 12             21228           21228           21228
# 13             24065           24065           24065
# 14       W.E.P. 5734        wep 5734        wep 5734
# 15     SC/PARIS 2167    scparis 2167    scparis 2166
# 16            233734          233734          233734
# 17              2692            2692            2692
# 18  STON/O2. 3101270  stono2 3101270  stono2 3101270
# 19              2696            2696            2696
# ===== Cabin =====
#    Cabin Cabin_clean Cabin_deduped
# 0    NaN         nan           nan
# 1    NaN         nan           nan
# 2    NaN         nan           nan
# 3    NaN         nan           nan
# 4    NaN         nan           nan
# 5    NaN         nan           nan
# 6    NaN         nan           nan
# 7    NaN         nan           nan
# 8    NaN         nan           nan
# 9    NaN         nan           nan
# 10   NaN         nan           nan
# 11   NaN         nan           nan
# 12   B45         b45           b45
# 13   NaN         nan           nan
# 14   E31         e31           e31
# 15   NaN         nan           nan
# 16   NaN         nan           nan
# 17   NaN         nan           nan
# 18   NaN         nan           nan
# 19   NaN         nan           nan
# ===== Embarked =====
#    Embarked Embarked_clean Embarked_deduped
# 0         Q              q                q
# 1         S              s                s
# 2         Q              q                q
# 3         S              s                s
# 4         S              s                s
# 5         S              s                s
# 6         Q              q                q
# 7         S              s                s
# 8         C              c                c
# 9         S              s                s
# 10        S              s                s
# 11        S              s                s
# 12        S              s                s
# 13        S              s                s
# 14        S              s                s
# 15        C              c                c
# 16        Q              q                q
# 17        C              c                c
# 18        S              s                s
# 19        C              c                c
